# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load all dataset
df = pd.read_csv('Downloads\painters.csv')

# %%
df
# Out:
#            rownames  Composition  Drawing  Colour  Expression School
# 0          Da Udine           10        8      16           3      A
# 1          Da Vinci           15       16       4          14      A
# 2        Del Piombo            8       13      16           7      A
# 3         Del Sarto           12       16       9           8      A
# 4         Fr. Penni            0       15       8           0      A
# 5     Guilio Romano           15       16       4          14      A
# 6      Michelangelo            8       17       4           8      A
# 7   Perino del Vaga           15       16       7           6      A
# 8          Perugino            4       12      10           4      A
# 9           Raphael           17       18      12          18      A
# 10       F. Zucarro           10       13       8           8      B
# 11     Fr. Salviata           13       15       8           8      B
# 12       Parmigiano           10       15       6           6      B
# ...

# %%
#check for the no of rows
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rownames     54 non-null     object
#  1   Composition  54 non-null     int64
#  2   Drawing      54 non-null     int64
#  3   Colour       54 non-null     int64
#  4   Expression   54 non-null     int64
#  5   School       54 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 2.7+ KB

# %%
#check for the first ten
df.head(10)
# Out:
#           rownames  Composition  Drawing  Colour  Expression School
# 0         Da Udine           10        8      16           3      A
# 1         Da Vinci           15       16       4          14      A
# 2       Del Piombo            8       13      16           7      A
# 3        Del Sarto           12       16       9           8      A
# 4        Fr. Penni            0       15       8           0      A
# 5    Guilio Romano           15       16       4          14      A
# 6     Michelangelo            8       17       4           8      A
# 7  Perino del Vaga           15       16       7           6      A
# 8         Perugino            4       12      10           4      A
# 9          Raphael           17       18      12          18      A

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data, bins=20, kde=True)  # Adjust the 'column_name' to your specific column
plt.title('Histogram of Data Distribution')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)  # Adjust the 'column_name' to your specific column
plt.title('Boxplot of Data Distribution')
plt.xlabel('Values')
plt.show()

# %%
# Create a scatterplot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Drawing', y='Colour', data=data)
plt.title('Scatterplot of Drawing Score vs Colour Score')
plt.xlabel('Drawing Score')
plt.ylabel('Colour Score')
plt.show()
